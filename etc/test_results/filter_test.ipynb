# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
file_name = "/home/lumos/tricat/src/tricat221/etc/test_results/2022-05-14_22-46-59.csv"
df = pd.read_csv(file_name, header=None)

# %%
df.head()
# Out:
#               0            1         2         3         4         5  \
# 0  1.651207e+09  796453727.0 -0.000033  0.000010  0.000055 -0.000033
# 1  1.651207e+09  796453727.0 -0.000033  0.000010  0.000055 -0.000033
# 2  1.651207e+09  898515473.0 -0.000035  0.000009  0.000055 -0.000034
# 3  1.651207e+09  994377416.0 -0.000034  0.000011  0.000056 -0.000034
# 4  1.651207e+09   97292057.0 -0.000032  0.000008  0.000055 -0.000034
#
#           6         7
# 0  0.000010  0.000055
# 1  0.000010  0.000055
# 2  0.000009  0.000055
# 3  0.000010  0.000055
# 4  0.000009  0.000055

# %%
raw_x = df.iloc[:, 2]
f_x = df.iloc[:, 5]

raw_y = df.iloc[:, 3]
f_y = df.iloc[:, 6]

raw_z = df.iloc[:, 4]
f_z = df.iloc[:, 7]

plt.figure(figsize=(20, 18))

plt.subplot(3, 1, 1)
plt.title('x')
plt.plot(raw_x, '-', color='dodgerblue', label='original')
plt.plot(f_x, 'r-', label='filtered_x')
plt.legend()

plt.subplot(3, 1, 2)
plt.title('y')
plt.plot(raw_y, '-', color='dodgerblue', label='original')
plt.plot(f_y, 'r-', label='filtered_y')
plt.legend()

plt.subplot(3, 1, 3)
plt.title('z')
plt.plot(raw_z, '-', color='dodgerblue', label='original')
plt.plot(f_z, 'r-', label='filtered_z')
plt.legend()

plt.tight_layout()
plt.savefig('imu_mag_filter.jpg')
plt.show()

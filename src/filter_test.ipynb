# %%
def temp(input):
    print(len(input))
    input.append(1)
    return input

# %%
import numpy as np

x = [[1, 2, 3], [4, 5, 6]]

result = np.asarray(x)
print(result)

result.transpose
print(result)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np

x = [[1, 2, 3], [4, 5, 6]]

result = np.asarray(x)
print(result)
np.transpose(result)
print(result)
np.savetxt("temp.csv", result, delimiter=",")
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[1 2 3]
#  [4 5 6]]

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
file_name = "/home/lumos/tricat/src/tricat221/src/2022-05-14_22-46-59.csv"
df = pd.read_csv(file_name, header=None)

# %%
df
# Out:
#                  0            1         2         3         4         5  \
# 0     1.651207e+09  796453727.0 -0.000033  0.000010  0.000055 -0.000033
# 1     1.651207e+09  796453727.0 -0.000033  0.000010  0.000055 -0.000033
# 2     1.651207e+09  898515473.0 -0.000035  0.000009  0.000055 -0.000034
# 3     1.651207e+09  994377416.0 -0.000034  0.000011  0.000056 -0.000034
# 4     1.651207e+09   97292057.0 -0.000032  0.000008  0.000055 -0.000034
# ...            ...          ...       ...       ...       ...       ...
# 996   1.651207e+09  373475433.0 -0.000038 -0.000030  0.000054 -0.000038
# 997   1.651207e+09  475438296.0 -0.000038 -0.000035  0.000057 -0.000038
# 998   1.651207e+09  583703534.0 -0.000036 -0.000031  0.000055 -0.000037
# 999   1.651207e+09  676089443.0 -0.000038 -0.000030  0.000054 -0.000038
# 1000  1.651207e+09  775434150.0 -0.000037 -0.000031  0.000053 -0.000037
#
#              6         7
# 0     0.000010  0.000055
# 1     0.000010  0.000055
# ...

# %%
raw_x = df.iloc[:, 2]
f_x = df.iloc[:, 5]

raw_y = df.iloc[:, 3]
f_y = df.iloc[:, 6]

raw_z = df.iloc[:, 4]
f_z = df.iloc[:, 7]

plt.figure(figsize=(25, 18))

plt.subplot(3, 1, 1)
plt.title('x')
plt.plot(raw_x, '.', color='dodgerblue', label='original')
plt.plot(f_x, 'r-', label='filtered_x')
plt.legend()

plt.subplot(3, 1, 2)
plt.title('y')
plt.plot(raw_y, '.', color='dodgerblue', label='original')
plt.plot(f_y, 'r-', label='filtered_y')
plt.legend()

plt.subplot(3, 1, 3)
plt.title('z')
plt.plot(raw_z, 'b-', color='dodgerblue', label='original')
plt.plot(f_z, 'r-', label='filtered_z')
plt.legend()

plt.tight_layout()
plt.show()
